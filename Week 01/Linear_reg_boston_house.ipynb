# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

data = pd.read_csv("boston_train.csv")
data.head()
# Out:
#       ID    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0      1  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1      2   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2      4   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 3      5   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 4      7  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2
# ..   ...   ...    ...   ...    ...    ...   ...     ...  ...  ...      ...
# 328  500   0.0   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2
# 329  502   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 330  503   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 331  504   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 332  506   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#       black  lstat  medv
# 0    396.90   4.98  24.0
# 1    396.90   9.14  21.6
# 2    394.63   2.94  33.4
# 3    396.90   5.33  36.2
# 4    395.60  12.43  22.9
# ..      ...    ...   ...
# 328  395.77  15.10  17.5
# 329  391.99   9.67  22.4
# 330  396.90   9.08  20.6
# 331  396.90   5.64  23.9
# 332  396.90   7.88  11.9
#
# [333 rows x 14 columns]

# %%
x=data[['crim','zn','indus','chas','nox','rm','age','dis','rad','tax']]
y=data['medv']
#print(y)
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(X_test)

# %%
plt.scatter(y_test,pred)
plt.xlabel('y test')
plt.ylabel('pred y')
# Out:
# Text(0, 0.5, 'pred y')

# %%
from sklearn import metrics

print('MAE',metrics.mean_absolute_error(y_test,pred))
# Out:
# MAE 4.4341550703173755
